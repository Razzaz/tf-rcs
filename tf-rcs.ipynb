# %%
import tensorflow as tf
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import zipfile,os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
from google.colab import files
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import load_model

# %%
# !wget --no-check-certificate \
  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip \
  -O /tmp/rockpaperscissors.zip
# Out:
# --2020-06-25 05:44:35--  https://dicodingacademy.blob.core.windows.net/picodiploma/ml_pemula_academy/rockpaperscissors.zip
# Resolving dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)... 52.239.197.36
# Connecting to dicodingacademy.blob.core.windows.net (dicodingacademy.blob.core.windows.net)|52.239.197.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322873683 (308M) [application/zip]
# Saving to: ‘/tmp/rockpaperscissors.zip’
#
# /tmp/rockpapersciss 100%[===================>] 307.92M   148MB/s    in 2.1s
#
# 2020-06-25 05:44:38 (148 MB/s) - ‘/tmp/rockpaperscissors.zip’ saved [322873683/322873683]

# %%
local_zip = '/tmp/rockpaperscissors.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
pip install split_folders
# Out:
# Requirement already satisfied: split_folders in /usr/local/lib/python3.6/dist-packages (0.3.1)

# %%
import split_folders
split_folders.ratio('/tmp/rockpaperscissors/rps-cv-images', output='/tmp/rockpaperscissors/data', seed=1337, ratio=(.8,.2))

base_dir = '/tmp/rockpaperscissors/data'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
# Out:
# Copying files: 2188 files [00:00, 3264.59 files/s]

# %%
os.listdir('/tmp/rockpaperscissors/data/train')
# Out:
# ['paper', 'scissors', 'rock']

# %%
os.listdir('/tmp/rockpaperscissors/data/val')
# Out:
# ['paper', 'scissors', 'rock']

# %%
training_datagen = ImageDataGenerator(rescale=1./255,
                        height_shift_range=0.2,
                        horizontal_flip=True,
                        vertical_flip=True)

validation_datagen = ImageDataGenerator(validation_split=0.2,
                        rescale=1./255)

augs_datagen = ImageDataGenerator(rescale=1./255,
                        horizontal_flip=True,
                        height_shift_range=.2,
                        vertical_flip = True,
                        validation_split = 0.2)

# %%
train_generator = training_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        shuffle=True)
 
validation_generator = augs_datagen.flow_from_directory(
        validation_dir, 
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 1749 images belonging to 3 classes.
# Found 439 images belonging to 3 classes.

# %%
earlystop = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=10,
    verbose=1,
    mode='min'
)

checkpoint = ModelCheckpoint(
    'best_model.h5',
    monitor='val_accuracy',
    verbose=1,
    save_best_only=True,
    mode='max',
    save_weights_only=False
)

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
history = model.fit(train_generator,
          steps_per_epoch=55,
          epochs=25,
          validation_data=validation_generator,
          #validation_steps=5,
          verbose=1,
          callbacks = [earlystop, checkpoint])

saved_model = load_model('best_model.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 3,473,475
# Trainable params: 3,473,475
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 55/55 [==============================] - ETA: 0s - loss: 1.1992 - accuracy: 0.3917
# Epoch 00001: val_accuracy improved from -inf to 0.50342, saving model to best_model.h5
# 55/55 [==============================] - 16s 284ms/step - loss: 1.1992 - accuracy: 0.3917 - val_loss: 1.0307 - val_accuracy: 0.5034
# Epoch 2/25
# 55/55 [==============================] - ETA: 0s - loss: 0.7248 - accuracy: 0.7050
# Epoch 00002: val_accuracy improved from 0.50342 to 0.82232, saving model to best_model.h5
# 55/55 [==============================] - 15s 272ms/step - loss: 0.7248 - accuracy: 0.7050 - val_loss: 0.4310 - val_accuracy: 0.8223
# Epoch 3/25
# 55/55 [==============================] - ETA: 0s - loss: 0.3423 - accuracy: 0.8788
# Epoch 00003: val_accuracy improved from 0.82232 to 0.90205, saving model to best_model.h5
# 55/55 [==============================] - 15s 270ms/step - loss: 0.3423 - accuracy: 0.8788 - val_loss: 0.2769 - val_accuracy: 0.9021
# Epoch 4/25
# 55/55 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.9108
# Epoch 00004: val_accuracy did not improve from 0.90205
# 55/55 [==============================] - 15s 271ms/step - loss: 0.2550 - accuracy: 0.9108 - val_loss: 0.3058 - val_accuracy: 0.8884
# Epoch 5/25
# 55/55 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.9377
# Epoch 00005: val_accuracy improved from 0.90205 to 0.93850, saving model to best_model.h5
# 55/55 [==============================] - 15s 274ms/step - loss: 0.1840 - accuracy: 0.9377 - val_loss: 0.2040 - val_accuracy: 0.9385
# Epoch 6/25
# 55/55 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9411
# Epoch 00006: val_accuracy did not improve from 0.93850
# 55/55 [==============================] - 15s 275ms/step - loss: 0.1654 - accuracy: 0.9411 - val_loss: 0.4976 - val_accuracy: 0.8383
# Epoch 7/25
# 55/55 [==============================] - ETA: 0s - loss: 0.1495 - accuracy: 0.9457
# Epoch 00007: val_accuracy improved from 0.93850 to 0.95216, saving model to best_model.h5
# 55/55 [==============================] - 15s 274ms/step - loss: 0.1495 - accuracy: 0.9457 - val_loss: 0.1564 - val_accuracy: 0.9522
# Epoch 8/25
# 55/55 [==============================] - ETA: 0s - loss: 0.1508 - accuracy: 0.9588
# Epoch 00008: val_accuracy improved from 0.95216 to 0.96355, saving model to best_model.h5
# 55/55 [==============================] - 15s 274ms/step - loss: 0.1508 - accuracy: 0.9588 - val_loss: 0.1074 - val_accuracy: 0.9636
# Epoch 9/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9708
# Epoch 00009: val_accuracy did not improve from 0.96355
# 55/55 [==============================] - 15s 276ms/step - loss: 0.0915 - accuracy: 0.9708 - val_loss: 0.1551 - val_accuracy: 0.9636
# Epoch 10/25
# 55/55 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9691
# Epoch 00010: val_accuracy did not improve from 0.96355
# 55/55 [==============================] - 15s 271ms/step - loss: 0.1038 - accuracy: 0.9691 - val_loss: 0.1625 - val_accuracy: 0.9636
# Epoch 11/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0895 - accuracy: 0.9743
# Epoch 00011: val_accuracy improved from 0.96355 to 0.97950, saving model to best_model.h5
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0895 - accuracy: 0.9743 - val_loss: 0.0926 - val_accuracy: 0.9795
# Epoch 12/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9743
# Epoch 00012: val_accuracy did not improve from 0.97950
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0865 - accuracy: 0.9743 - val_loss: 0.2035 - val_accuracy: 0.9544
# Epoch 13/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9754
# Epoch 00013: val_accuracy improved from 0.97950 to 0.98633, saving model to best_model.h5
# 55/55 [==============================] - 15s 270ms/step - loss: 0.0792 - accuracy: 0.9754 - val_loss: 0.1122 - val_accuracy: 0.9863
# Epoch 14/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9777
# Epoch 00014: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 270ms/step - loss: 0.0947 - accuracy: 0.9777 - val_loss: 0.2082 - val_accuracy: 0.9590
# Epoch 15/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0684 - accuracy: 0.9806
# Epoch 00015: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 275ms/step - loss: 0.0684 - accuracy: 0.9806 - val_loss: 0.2201 - val_accuracy: 0.9408
# Epoch 16/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9817
# Epoch 00016: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0681 - accuracy: 0.9817 - val_loss: 0.2812 - val_accuracy: 0.8998
# Epoch 17/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9806
# Epoch 00017: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 271ms/step - loss: 0.0767 - accuracy: 0.9806 - val_loss: 0.0951 - val_accuracy: 0.9818
# Epoch 18/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9823
# Epoch 00018: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 268ms/step - loss: 0.0635 - accuracy: 0.9823 - val_loss: 0.1606 - val_accuracy: 0.9841
# Epoch 19/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9840
# Epoch 00019: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0525 - accuracy: 0.9840 - val_loss: 0.1544 - val_accuracy: 0.9795
# Epoch 20/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9788
# Epoch 00020: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 272ms/step - loss: 0.0694 - accuracy: 0.9788 - val_loss: 0.0915 - val_accuracy: 0.9841
# Epoch 21/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9811
# Epoch 00021: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0576 - accuracy: 0.9811 - val_loss: 0.2890 - val_accuracy: 0.9567
# Epoch 22/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0527 - accuracy: 0.9857
# Epoch 00022: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0527 - accuracy: 0.9857 - val_loss: 0.0824 - val_accuracy: 0.9795
# Epoch 23/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9874
# Epoch 00023: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 270ms/step - loss: 0.0450 - accuracy: 0.9874 - val_loss: 0.1596 - val_accuracy: 0.9818
# Epoch 24/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9851
# Epoch 00024: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 269ms/step - loss: 0.0616 - accuracy: 0.9851 - val_loss: 0.2480 - val_accuracy: 0.9522
# Epoch 25/25
# 55/55 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9840
# Epoch 00025: val_accuracy did not improve from 0.98633
# 55/55 [==============================] - 15s 274ms/step - loss: 0.0607 - accuracy: 0.9840 - val_loss: 0.1713 - val_accuracy: 0.9704

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.plot(epochs_range, acc, 'r', label='Training Accuracy')
plt.plot(epochs_range, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()



plt.plot(epochs_range, loss, 'r', label='Loss')
plt.plot(epochs_range, val_loss, 'b', label='Validation Loss')
plt.title('Loss and Loss Validation')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# %matplotlib inline
 
uploaded = files.upload()
 
for fn in uploaded.keys():
 
  path = fn
  img = image.load_img(path, target_size=(150,150))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
 
  images = np.vstack([x])
  classes = model.predict(images, batch_size=32)
  
  print(fn)
  if classes[0][0] == 1:
    print('paper')
  elif classes[0][1] == 1:
    print('rock')
  elif classes[0][2] == 1:
    print('scissors')
# Out:
#      <input type="file" id="files-d28d91e6-8495-4fd9-a91d-20d9ee011f02" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d28d91e6-8495-4fd9-a91d-20d9ee011f02">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hand.jpg to hand (1).jpg
# hand.jpg
# paper
